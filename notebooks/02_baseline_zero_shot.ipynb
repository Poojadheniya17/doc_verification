# %% [markdown]
# # 02 — Baseline: Zero-Shot Qwen2.5-VL + OCR
#
# Scaffolded in Phase 1. Populated in Phase 3 — visualizes results from `src/eval/clean_eval.py` and `src/utils/ocr_baseline.py` (the 'before' numbers everything else is measured against).
#
# No pipeline logic here — this notebook only loads and plots results already computed by `src/` scripts.
