# %% [markdown]
# # 01 — Data Exploration
#
# Scaffolded in Phase 1. Populated in Phase 2 once MIDV-2020 is acquired and Tier 1/2 forgeries + degradations are generated.
#
# This notebook is for exploration/visualization only — no pipeline logic lives here (that stays in `src/`, per the config-driven design).
